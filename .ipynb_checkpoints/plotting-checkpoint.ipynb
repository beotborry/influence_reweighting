# %%
import matplotlib.pyplot as plt
import pickle

# %%
# utkface trng acc by epoch
dataset = "utkface"
seed = 100

filename1 = "./image_log/{}_seed_{}_bottom_k_{}_log.txt"
filename2 = "./image_log/{}_seed_{}_k_{}_log.txt"

for k in range(100, 500, 100):
    try:
        with open(filename1.format(dataset, seed, k), "rb") as fp:
            log = pickle.load(fp)
            plt.plot(log[0], label="bottom_trng_acc_k_{}".format(k))
            
            #print(log[0], log[1])
            #plt.plot(log[0], label="bottom_trng_acc_k_{}".format(k))
            #plt.plot(log[2], label="bottom_valid")

            #plt.plot(log[4], label="bottom_test_acc_k_{}".format(k))
            #plt.plot(log[5], label="bottom_test_fair_k_{}".format(k))
            #plt.scatter(log[4][20:], log[5][20:], label='{}'.format(k))
    except:
        continue
    try:
        with open(filename2.format(dataset, seed, k), "rb") as fp:
            log = pickle.load(fp)
            plt.plot(log[0], label="top_trng_acc_k_{}".format(k))
            #plt.plot(log[0], label="top_trng_acc")
            #plt.plot(log[2], label="top_valid_acc")

            #plt.plot(log[2], label="top_test_acc_k_{}".format(k))
            #plt.plot(log[5], label="top_test_fair_k_{}".format(k))
            #plt.scatter(log[4][20:], log[5][20:], label='{}'.format(k))
    except:
        continue
        
plt.xlabel("Epoch", labelpad=10)
plt.ylabel("Test Fair", labelpad=10)
plt.legend()

plt.show()

# %%
# utkface valid acc by epoch
dataset = "utkface"
seed = 100

filename1 = "./image_log/{}_seed_{}_bottom_k_{}_log.txt"
filename2 = "./image_log/{}_seed_{}_k_{}_log.txt"

for k in range(100, 500, 100):
    try:
        with open(filename1.format(dataset, seed, k), "rb") as fp:
            log = pickle.load(fp)
            plt.plot(log[0], label="bottom_valid_acc_k_{}".format(k))
            
            #print(log[0], log[1])
            #plt.plot(log[0], label="bottom_trng_acc_k_{}".format(k))
            #plt.plot(log[2], label="bottom_valid")

            #plt.plot(log[4], label="bottom_test_acc_k_{}".format(k))
            #plt.plot(log[5], label="bottom_test_fair_k_{}".format(k))
            #plt.scatter(log[4][20:], log[5][20:], label='{}'.format(k))
    except:
        continue
    try:
        with open(filename2.format(dataset, seed, k), "rb") as fp:
            log = pickle.load(fp)
            plt.plot(log[0], label="top_valid_acc_k_{}".format(k))
            #plt.plot(log[0], label="top_trng_acc")
            #plt.plot(log[2], label="top_valid_acc")

            #plt.plot(log[2], label="top_test_acc_k_{}".format(k))
            #plt.plot(log[5], label="top_test_fair_k_{}".format(k))
            #plt.scatter(log[4][20:], log[5][20:], label='{}'.format(k))
    except:
        continue
        
plt.xlabel("Epoch", labelpad=10)
plt.ylabel("Test Fair", labelpad=10)
plt.legend()

plt.show()

# %%
# utkface test acc by epoch
dataset = "utkface"
seed = 100

filename1 = "./image_log/{}_seed_{}_bottom_k_{}_log.txt"
filename2 = "./image_log/{}_seed_{}_k_{}_log.txt"

for k in range(100, 500, 1000):
    try:
        with open(filename1.format(dataset, seed, k), "rb") as fp:
            log = pickle.load(fp)
            plt.plot(log[4], label="bottom_test_acc_k_{}".format(k))
            
            #print(log[0], log[1])
            #plt.plot(log[0], label="bottom_trng_acc_k_{}".format(k))
            #plt.plot(log[2], label="bottom_valid")

            #plt.plot(log[4], label="bottom_test_acc_k_{}".format(k))
            #plt.plot(log[5], label="bottom_test_fair_k_{}".format(k))
            #plt.scatter(log[4][20:], log[5][20:], label='{}'.format(k))
    except:
        continue
    try:
        with open(filename2.format(dataset, seed, k), "rb") as fp:
            log = pickle.load(fp)
            plt.plot(log[4], label="top_test_acc_k_{}".format(k))
            #plt.plot(log[0], label="top_trng_acc")
            #plt.plot(log[2], label="top_valid_acc")

            #plt.plot(log[2], label="top_test_acc_k_{}".format(k))
            #plt.plot(log[5], label="top_test_fair_k_{}".format(k))
            #plt.scatter(log[4][20:], log[5][20:], label='{}'.format(k))
    except:
        continue
        
plt.xlabel("Epoch", labelpad=10)
plt.ylabel("Test Acc", labelpad=10)
plt.legend()

plt.show()

# %%
# celeba test fair by epoch
dataset = "celeba"
seed = 100

filename1 = "./image_log/{}_seed_{}_bottom_k_{}_log.txt"
filename2 = "./image_log/{}_seed_{}_k_{}_log.txt"

for k in range(100, 500, 50):
    try:
        with open(filename1.format(dataset, seed, k), "rb") as fp:
            log = pickle.load(fp)
            plt.plot(log[4], label="bottom_test_acc_k_{}".format(k))
            
            #print(log[0], log[1])
            #plt.plot(log[0], label="bottom_trng_acc_k_{}".format(k))
            #plt.plot(log[2], label="bottom_valid")

            #plt.plot(log[4], label="bottom_test_acc_k_{}".format(k))
            #plt.plot(log[5], label="bottom_test_fair_k_{}".format(k))
            #plt.scatter(log[4][20:], log[5][20:], label='{}'.format(k))
    except:
        continue
    try:
        with open(filename2.format(dataset, seed, k), "rb") as fp:
            log = pickle.load(fp)
            plt.plot(log[4], label="top_test_acc_k_{}".format(k))
            #plt.plot(log[0], label="top_trng_acc")
            #plt.plot(log[2], label="top_valid_acc")

            #plt.plot(log[2], label="top_test_acc_k_{}".format(k))
            #plt.plot(log[5], label="top_test_fair_k_{}".format(k))
            #plt.scatter(log[4][20:], log[5][20:], label='{}'.format(k))
    except:
        continue
        
plt.xlabel("Epoch", labelpad=10)
plt.ylabel("Test Acc", labelpad=10)
plt.legend()

plt.show()

# %%
with open("./image_log/utkface_seed_0_naive_log.txt", "rb") as fp:
    log = pickle.load(fp)
    
    plt.plot(log[0], label="trng acc")
    plt.plot(log[2], label="valid acc")
    plt.plot(log[4], label="test acc")
    
plt.legend()
plt.show()

# %%
from pprint import pprint
with open("./utkface_influence_score_seed_100.txt", "rb") as fp:
    influence_score = pickle.load(fp)
    pprint(sorted(influence_score)[-100:])
# Out:
# [0.09513873606920242,
#  0.09539452195167542,
#  0.09569726139307022,
#  0.09594666957855225,
#  0.09623350203037262,
#  0.09686654806137085,
#  0.09731806814670563,
#  0.09734050184488297,
#  0.09845460206270218,
#  0.09891752153635025,
#  0.09896238148212433,
#  0.09912961721420288,
#  0.09920694679021835,
#  0.09947752207517624,
#  0.09960968047380447,
#  0.10003221035003662,
#  0.10036477446556091,
#  0.10043293237686157,
#  0.10086487233638763,
#  0.10096119344234467,
#  0.10136239230632782,
#  0.10342593491077423,
#  0.1034766435623169,
#  0.10454278439283371,
#  0.1053483635187149,
#  0.1055859699845314,
#  0.10582958161830902,
#  0.10636289417743683,
#  0.10664385557174683,
#  0.10698974132537842,
#  0.10713137686252594,
#  0.1072038933634758,
#  0.10751214623451233,
#  0.1080777645111084,
#  0.10856737196445465,
#  0.10917521268129349,
#  0.10979624092578888,
#  0.11023744195699692,
#  0.11169121414422989,
#  0.11200728267431259,
#  0.11220068484544754,
# ...

# %%
with open("./adult_influence_score_seed_1.txt", "rb") as fp:
    influence_score = pickle.load(fp)
    pprint(sorted(influence_score)[-100:])
# Out:
# [0.020028024911880493,
#  0.020028024911880493,
#  0.020049840211868286,
#  0.0201543178409338,
#  0.020181789994239807,
#  0.020194079726934433,
#  0.02020997367799282,
#  0.02022501453757286,
#  0.020237216725945473,
#  0.020271802321076393,
#  0.020489118993282318,
#  0.020532239228487015,
#  0.020579075440764427,
#  0.020680267363786697,
#  0.020758524537086487,
#  0.020758524537086487,
#  0.02092933841049671,
#  0.02092933841049671,
#  0.02092933841049671,
#  0.021079853177070618,
#  0.021165212616324425,
#  0.0212201327085495,
#  0.0212201327085495,
#  0.0212201327085495,
#  0.02124091610312462,
#  0.021363841369748116,
#  0.021363841369748116,
#  0.02137657254934311,
#  0.02138754539191723,
#  0.021513741463422775,
#  0.02152043581008911,
#  0.021795490756630898,
#  0.02193632163107395,
#  0.02193632163107395,
#  0.021966401487588882,
#  0.02202252298593521,
#  0.02212557941675186,
#  0.022147873416543007,
#  0.022181479260325432,
#  0.022466035559773445,
# ...
